# %% [markdown]
# ## Wills Kookogey PyTorch Learning Enviromnment

# %% [markdown]
# ### Setup and Hyperparameters

# %% [markdown]
# Vars of interest
#
# {
#
#     "IMU_0":["GyrX", "GyrY", "GyrZ", "AccX", "AccY", "AccZ"],
#     "ATT":["DesRoll", "Roll", "DesPitch", "Pitch", "DesYaw", "Yaw"],
#     "RCIN":["C6", "C7"]
# }
#
# RCIN to determine when leak started for labeling, NOT used as model input

# %%
import fennec_ml as fn
import FID_utils as FID
import os
from pathlib import Path
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms  as transforms
import matplotlib.pyplot as plt
# %matplotlib inline

# hyper parameters
train_split = 0.8
input_size = 12
hidden_size = 64
num_classes = 4
num_epochs = 50
batch_size = 64
test_batch_size = 1
learning_rate = 0.001
weight_decay = 1e-3
dropout = 0.3
patience = 7  # number of epochs to wait for improvement before early stopping

sequence_length = 80
num_layers = 2

model_name = "fid_model_4_4.pth"
# test_flights = ["194B_LR", "195B_R", "188B_L", "189B_NONE"]
test_flights = ["175B_LR", "188B_L", "191B_R", "178B_NONE"]

# %% [markdown]
# ### Folder Config

# %%
# folder config
main_dir = os.getcwd()
data_dir = os.path.join(main_dir, "DATA")
os.makedirs(data_dir, exist_ok=True)
excel_dir = os.path.join(data_dir, "RAW_DATA/FID3")
os.makedirs(excel_dir, exist_ok=True)
csv_dir = os.path.join(data_dir, "PROCESSED_DATA/FID4_4")
test_csv_dir = os.path.join(csv_dir, "test_flights")
os.makedirs(csv_dir, exist_ok=True)
os.makedirs(test_csv_dir, exist_ok=True)

json_path = os.path.join(main_dir, "vars_of_interest.json")

# Create models directory 
model_path = Path("models")
model_path.mkdir(parents=True, exist_ok=True)

# Create model save path
model_save_path = model_path / model_name

# convert excel data to csv
print("Using folder_cleaner() to convert from raw excel files to .csv's only including vars of interest.\nfolder_cleaner() output:")
fn.folder_cleaner(excel_dir, csv_dir, test_flight_names=test_flights, skip=True, overwrite=False, downsample=False)

# convert csv to numpy arrays
train_val_data = fn.csv_to_numpy(csv_dir, start_index=0)
test_data = fn.csv_to_numpy(test_csv_dir, start_index=0)

# standardize data
train_val_data, test_data = fn.scale(train_val_data, test_data, scaler="standard")

# get FID labels and leakstarts
train_val_labels, train_val_leakstarts = FID.get_FID_labels(csv_dir)
test_labels, test_leakstarts = FID.get_FID_labels(test_csv_dir)

# nudge leakstarts back by 2 seconds to account for leak start (800 timesteps at 400hz)
train_val_leakstarts = [leakstart + 800 for leakstart in train_val_leakstarts]
test_leakstarts = [leakstart + 800 for leakstart in test_leakstarts]

# verify flights found
num_train_val_flights = len(train_val_labels)
print(f"Found {num_train_val_flights} flights for training and validation")

num_test_flights = len(test_labels)
print(f"Found {num_test_flights} flights for testing")

# segment and label data
dataset_dict = FID.segment_label_split_sliding_FID(train_val_data, test_data, train_val_labels, test_labels, train_val_leakstarts, test_leakstarts, sequence_length, train_split,shuffle=True, stride=None)
# Out:
# Using folder_cleaner() to convert from raw excel files to .csv's only including vars of interest.
# folder_cleaner() output:
# Sheet RCIN, upsampled by 40.0
# 179B_LR.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 179B_LR.csv
# Sheet RCIN, upsampled by 40.0
# 182B_NONE.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 182B_NONE.csv
# Warning: No saved leak start for skipped file 182B_NONE
# Sheet RCIN, upsampled by 40.0
# 193B_NONE.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 193B_NONE.csv
# Warning: No saved leak start for skipped file 193B_NONE
# Sheet RCIN, upsampled by 40.0
# 187B_R.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 187B_R.csv
# Sheet RCIN, upsampled by 40.0
# 169B_L.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 169B_L.csv
# Sheet RCIN, upsampled by 40.0
# 172B_R.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 172B_R.csv
# Sheet RCIN, upsampled by 40.0
# 178B_NONE.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4/test_flights as 178B_NONE.csv
# Warning: No saved leak start for skipped file 178B_NONE
# Sheet RCIN, upsampled by 40.0
# 211B_NONE.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 211B_NONE.csv
# Warning: No saved leak start for skipped file 211B_NONE
# Sheet RCIN, upsampled by 40.0
# 186B_LR.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 186B_LR.csv
# Sheet RCIN, upsampled by 40.0
# 214B_L.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 214B_L.csv
# Sheet RCIN, upsampled by 40.0
# 168B_R.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 168B_R.csv
# Sheet RCIN, upsampled by 40.0
# 173B_L.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 173B_L.csv
# Sheet RCIN, upsampled by 40.0
# 190B_LR.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 190B_LR.csv
# Sheet RCIN, upsampled by 40.0
# 175B_LR.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4/test_flights as 175B_LR.csv
# Sheet RCIN, upsampled by 40.0
# 180B_R.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 180B_R.csv
# Sheet RCIN, upsampled by 40.0
# 167B_LR.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 167B_LR.csv
# Sheet RCIN, upsampled by 40.0
# 174B_NONE.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 174B_NONE.csv
# Warning: No saved leak start for skipped file 174B_NONE
# Sheet RCIN, upsampled by 40.0
# 208B_LR.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 208B_LR.csv
# Sheet RCIN, upsampled by 40.0
# 192B_L.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 192B_L.csv
# Sheet RCIN, upsampled by 40.0
# 210B_L.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 210B_L.csv
# Sheet RCIN, upsampled by 40.0
# 215B_NONE.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 215B_NONE.csv
# Warning: No saved leak start for skipped file 215B_NONE
# Sheet RCIN, upsampled by 40.0
# 177B_L.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 177B_L.csv
# Sheet RCIN, upsampled by 40.0
# 183B_NONE.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 183B_NONE.csv
# Warning: No saved leak start for skipped file 183B_NONE
# Sheet RCIN, upsampled by 40.0
# 171B_LR.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 171B_LR.csv
# Sheet RCIN, upsampled by 40.0
# 191B_R.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4/test_flights as 191B_R.csv
# Sheet RCIN, upsampled by 40.0
# 213B_R.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 213B_R.csv
# Sheet RCIN, upsampled by 40.0
# 189B_NONE.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 189B_NONE.csv
# Warning: No saved leak start for skipped file 189B_NONE
# Sheet RCIN, upsampled by 40.0
# 181B_L.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 181B_L.csv
# Sheet RCIN, upsampled by 40.0
# 188B_L.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4/test_flights as 188B_L.csv
# Sheet RCIN, upsampled by 40.0
# 212B_LR.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 212B_LR.csv
# Sheet RCIN, upsampled by 40.0
# 176B_R.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 176B_R.csv
# Sheet RCIN, upsampled by 40.0
# 209B_R.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_4 as 209B_R.csv
# Importing 167B_LR.csv with shape (70840, 12)...
# Importing 168B_R.csv with shape (55420, 12)...
# Importing 169B_L.csv with shape (62434, 12)...
# Importing 171B_LR.csv with shape (35840, 12)...
# Importing 172B_R.csv with shape (26240, 12)...
# Importing 173B_L.csv with shape (44920, 12)...
# Importing 174B_NONE.csv with shape (42483, 12)...
# Importing 176B_R.csv with shape (46600, 12)...
# Importing 177B_L.csv with shape (47720, 12)...
# Importing 179B_LR.csv with shape (49920, 12)...
# Importing 180B_R.csv with shape (52360, 12)...
# Importing 181B_L.csv with shape (47400, 12)...
# Importing 182B_NONE.csv with shape (44750, 12)...
# Importing 183B_NONE.csv with shape (49200, 12)...
# Importing 186B_LR.csv with shape (55320, 12)...
# Importing 187B_R.csv with shape (51471, 12)...
# Importing 189B_NONE.csv with shape (50960, 12)...
# Importing 190B_LR.csv with shape (54040, 12)...
# Importing 192B_L.csv with shape (56680, 12)...
# Importing 193B_NONE.csv with shape (51840, 12)...
# Importing 208B_LR.csv with shape (42360, 12)...
# Importing 209B_R.csv with shape (49760, 12)...
# Importing 210B_L.csv with shape (63830, 12)...
# Importing 211B_NONE.csv with shape (53245, 12)...
# Importing 212B_LR.csv with shape (53760, 12)...
# Importing 213B_R.csv with shape (53640, 12)...
# Importing 214B_L.csv with shape (51600, 12)...
# Importing 215B_NONE.csv with shape (57880, 12)...
# Importing 175B_LR.csv with shape (51223, 12)...
# Importing 178B_NONE.csv with shape (42920, 12)...
# Importing 188B_L.csv with shape (52176, 12)...
# Importing 191B_R.csv with shape (60800, 12)...
# Found 28 flights for training and validation
# Found 4 flights for testing
# Segments shuffled
# Segments not shuffled
# All data segmented and labeled!
# Training_Sets: 14217
# Validation_Sets: 3555
# Testing_Sets: 2588

# %% [markdown]
# ### Check Data Shape

# %%
print(dataset_dict["Training_Set"]["sets"].shape)
print(dataset_dict["Training_Set"]["labels"].shape)
print(dataset_dict["Validation_Set"]["sets"].shape)
print(dataset_dict["Validation_Set"]["labels"].shape)
print(dataset_dict["Testing_Set"]["sets"].shape)
print(dataset_dict["Testing_Set"]["labels"].shape)
# Out:
# (14217, 80, 12)
# (14217,)
# (3555, 80, 12)
# (3555,)
# (2588, 80, 12)
# (2588,)

# %% [markdown]
# ### Convert data to tensors

# %%
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler, TensorDataset
import numpy as np

encoder = LabelEncoder()

encoded_labels_train = encoder.fit_transform(dataset_dict["Training_Set"]["labels"])
print(encoder.classes_)
encoded_labels_val   = encoder.transform(dataset_dict["Validation_Set"]["labels"])
encoded_labels_test  = encoder.transform(dataset_dict["Testing_Set"]["labels"])

input_train = torch.from_numpy(dataset_dict["Training_Set"]["sets"]).type(torch.float)
output_train = torch.from_numpy(encoded_labels_train).long()

input_val = torch.from_numpy(dataset_dict["Validation_Set"]["sets"]).type(torch.float)
output_val = torch.from_numpy(encoded_labels_val).long()

input_test = torch.from_numpy(dataset_dict["Testing_Set"]["sets"]).type(torch.float)
output_test = torch.from_numpy(encoded_labels_test).long()

# stack inputs and outputs
train_data = TensorDataset(input_train, output_train)
val_data = TensorDataset(input_val, output_val)
test_data = TensorDataset(input_test, output_test)

# data loader
class_counts = np.bincount(output_train.numpy())
print(f'Num data segments per class: {class_counts}')
weights = 1. / class_counts
print(f'Weights per class: {weights}')
sample_weights = [weights[label] for label in output_train]
sampler = WeightedRandomSampler(sample_weights, num_samples=len(sample_weights), replacement=True)

# try shuffle = false
train_loader = DataLoader(train_data, batch_size=batch_size, sampler=sampler)
val_loader   = DataLoader(val_data, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(test_data, batch_size=test_batch_size, shuffle=False)
# Out:
# ['L' 'LR' 'NONE' 'R']
# Num data segments per class: [3089 2947 5356 2825]
# Weights per class: [0.00032373 0.00033933 0.00018671 0.00035398]

# %% [markdown]
# ### Build Model

# %%
from pathlib import Path
import torch
import torch.nn as nn
from torch.optim import Adam
import torchvision.transforms  as transforms
import matplotlib.pyplot as plt
# %matplotlib inline

# Device config
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("MPS device found.")
else:
    print("MPS device not found. Using CPU.")
    device = torch.device("cpu") # Fallback to CPU if MPS is not available

# GRU Model
class GRU(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout=dropout):
        super(GRU, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, num_layers,
                          batch_first=True, dropout=dropout if num_layers > 1 else 0)
        self.fc1 = nn.Linear(hidden_size, hidden_size // 2)
        self.dropout = nn.Dropout(dropout)
        self.fc2 = nn.Linear(hidden_size // 2, num_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        # GRU output
        out, _ = self.gru(x)   # out: [batch, seq, hidden]
        
        # Take only the last timestep
        out = out[:, -1, :]    # [batch, hidden]

        # Fully connected layers with dropout
        out = self.fc1(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.fc2(out)

        return out

model = GRU(input_size=input_size, hidden_size=hidden_size, num_classes=num_classes, num_layers=num_layers).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
best_val_loss = float('inf')
# Out:
# MPS device found.

# %% [markdown]
# ### Train Model

# %%
# Train Loop

# arrays to store training curve data
train_losses = []
val_losses = []
val_accuracies = []

no_improvement_epochs = 0

model.train()

for epoch in range(num_epochs):
    # Training
    model.train()
    running_loss = 0
    for input, output in train_loader:
        # print(f"Input shape: {input.shape}, Output shape: {output.shape}")
        input, output = input.to(device), output.to(device)
        optimizer.zero_grad()
        model_outputs = model(input)
        loss = criterion(model_outputs,output)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * input.size(0)
    epoch_loss = running_loss / len(train_data)

    # Validation
    model.eval()
    val_loss = 0
    correct = 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            loss = criterion(outputs,y_batch)
            val_loss += loss.item() * X_batch.size(0)
            preds = torch.argmax(outputs, dim=1)
            correct += (preds == y_batch).sum().item()
    val_loss /= len(val_data)
    val_acc = correct / len(val_data)

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
    
    # save each epoch's perormance
    train_losses.append(epoch_loss)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), model_save_path)
        print(f"✅ Saved best model at epoch {epoch+1}")
        no_improvement_epochs = 0 # reset counter if model improves
    
    else:
        no_improvement_epochs += 1
        if no_improvement_epochs >= patience:
            print("⏰ Early stopping")
            break

print("Training complete!")

epochs = range(1, len(train_losses) + 1)
# Out:
# Epoch 1/50, Train Loss: 1.3606, Val Loss: 1.3316, Val Acc: 0.3668
# ✅ Saved best model at epoch 1
# Epoch 2/50, Train Loss: 1.3519, Val Loss: 1.3311, Val Acc: 0.3643
# ✅ Saved best model at epoch 2
# Epoch 3/50, Train Loss: 1.3447, Val Loss: 1.3518, Val Acc: 0.3437
# Epoch 4/50, Train Loss: 1.3257, Val Loss: 1.2797, Val Acc: 0.4231
# ✅ Saved best model at epoch 4
# Epoch 5/50, Train Loss: 1.2388, Val Loss: 1.1990, Val Acc: 0.4720
# ✅ Saved best model at epoch 5
# Epoch 6/50, Train Loss: 1.1971, Val Loss: 1.1347, Val Acc: 0.4945
# ✅ Saved best model at epoch 6
# Epoch 7/50, Train Loss: 1.1621, Val Loss: 1.1146, Val Acc: 0.4976
# ✅ Saved best model at epoch 7
# Epoch 8/50, Train Loss: 1.1254, Val Loss: 1.1000, Val Acc: 0.5128
# ✅ Saved best model at epoch 8
# Epoch 9/50, Train Loss: 1.0493, Val Loss: 0.9633, Val Acc: 0.6042
# ✅ Saved best model at epoch 9
# Epoch 10/50, Train Loss: 0.7724, Val Loss: 0.7109, Val Acc: 0.7108
# ✅ Saved best model at epoch 10
# Epoch 11/50, Train Loss: 0.5987, Val Loss: 0.6269, Val Acc: 0.7331
# ✅ Saved best model at epoch 11
# Epoch 12/50, Train Loss: 0.5403, Val Loss: 0.5132, Val Acc: 0.7783
# ✅ Saved best model at epoch 12
# Epoch 13/50, Train Loss: 0.5318, Val Loss: 0.4850, Val Acc: 0.8031
# ✅ Saved best model at epoch 13
# Epoch 14/50, Train Loss: 0.4663, Val Loss: 0.4669, Val Acc: 0.8079
# ✅ Saved best model at epoch 14
# Epoch 15/50, Train Loss: 0.4474, Val Loss: 0.4243, Val Acc: 0.8197
# ✅ Saved best model at epoch 15
# Epoch 16/50, Train Loss: 0.4356, Val Loss: 0.4215, Val Acc: 0.8304
# ✅ Saved best model at epoch 16
# Epoch 17/50, Train Loss: 0.4141, Val Loss: 0.4158, Val Acc: 0.8253
# ✅ Saved best model at epoch 17
# Epoch 18/50, Train Loss: 0.4058, Val Loss: 0.4141, Val Acc: 0.8321
# ✅ Saved best model at epoch 18
# Epoch 19/50, Train Loss: 0.3917, Val Loss: 0.4061, Val Acc: 0.8270
# ✅ Saved best model at epoch 19
# Epoch 20/50, Train Loss: 0.3662, Val Loss: 0.4038, Val Acc: 0.8270
# ✅ Saved best model at epoch 20
# Epoch 21/50, Train Loss: 0.3560, Val Loss: 0.3916, Val Acc: 0.8416
# ✅ Saved best model at epoch 21
# Epoch 22/50, Train Loss: 0.3386, Val Loss: 0.3614, Val Acc: 0.8554
# ✅ Saved best model at epoch 22
# Epoch 23/50, Train Loss: 0.3431, Val Loss: 0.3773, Val Acc: 0.8520
# Epoch 24/50, Train Loss: 0.3249, Val Loss: 0.3413, Val Acc: 0.8636
# ✅ Saved best model at epoch 24
# Epoch 25/50, Train Loss: 0.3038, Val Loss: 0.3841, Val Acc: 0.8487
# Epoch 26/50, Train Loss: 0.2986, Val Loss: 0.3447, Val Acc: 0.8653
# Epoch 27/50, Train Loss: 0.2989, Val Loss: 0.3919, Val Acc: 0.8543
# Epoch 28/50, Train Loss: 0.2918, Val Loss: 0.3499, Val Acc: 0.8748
# Epoch 29/50, Train Loss: 0.2765, Val Loss: 0.3490, Val Acc: 0.8605
# Epoch 30/50, Train Loss: 0.2771, Val Loss: 0.3277, Val Acc: 0.8821
# ✅ Saved best model at epoch 30
# Epoch 31/50, Train Loss: 0.2577, Val Loss: 0.3126, Val Acc: 0.8743
# ✅ Saved best model at epoch 31
# Epoch 32/50, Train Loss: 0.2584, Val Loss: 0.3170, Val Acc: 0.8765
# Epoch 33/50, Train Loss: 0.2487, Val Loss: 0.2895, Val Acc: 0.8889
# ✅ Saved best model at epoch 33
# Epoch 34/50, Train Loss: 0.2530, Val Loss: 0.3256, Val Acc: 0.8810
# Epoch 35/50, Train Loss: 0.2599, Val Loss: 0.3129, Val Acc: 0.8771
# Epoch 36/50, Train Loss: 0.2350, Val Loss: 0.2845, Val Acc: 0.8875
# ✅ Saved best model at epoch 36
# Epoch 37/50, Train Loss: 0.2461, Val Loss: 0.3686, Val Acc: 0.8633
# Epoch 38/50, Train Loss: 0.2509, Val Loss: 0.3280, Val Acc: 0.8779
# Epoch 39/50, Train Loss: 0.2287, Val Loss: 0.2880, Val Acc: 0.8880
# Epoch 40/50, Train Loss: 0.2214, Val Loss: 0.2778, Val Acc: 0.8954
# ✅ Saved best model at epoch 40
# Epoch 41/50, Train Loss: 0.2145, Val Loss: 0.3181, Val Acc: 0.8889
# Epoch 42/50, Train Loss: 0.2315, Val Loss: 0.3008, Val Acc: 0.8844
# Epoch 43/50, Train Loss: 0.2106, Val Loss: 0.3056, Val Acc: 0.8855
# Epoch 44/50, Train Loss: 0.2018, Val Loss: 0.3556, Val Acc: 0.8785
# Epoch 45/50, Train Loss: 0.2085, Val Loss: 0.3187, Val Acc: 0.8869
# Epoch 46/50, Train Loss: 0.2014, Val Loss: 0.2886, Val Acc: 0.8914
# Epoch 47/50, Train Loss: 0.2062, Val Loss: 0.3100, Val Acc: 0.8906
# ⏰ Early stopping
# Training complete!

# %% [markdown]
# ### Plot Train/Val and Acc Curves

# %%
# Set Plot Styles
import matplotlib.pyplot as plt

plt.rcParams.update({
    "figure.figsize": (8, 6),
    "axes.edgecolor": "black",
    "axes.linewidth": .9,
    "axes.labelsize": 12,
    "axes.titlesize": 13,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "lines.linewidth": 1.8,
    "grid.linestyle": "--",
    "grid.alpha": 0.4,
})

# plot training and validation loss curves

plt.figure()
plt.plot(epochs, train_losses, label="Train Loss")
plt.plot(epochs, val_losses, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training & Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(epochs, val_accuracies, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Plot Confusion Matrix / Confidence Interval for Seen Flights

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

true_classes = encoder.classes_

correct_guesses = 0
total_guesses = 0
correctness = 0

all_true = []
all_preds = []
all_probs = []
all_confidences = []

model.load_state_dict(torch.load(model_save_path))
model.to(device)
model.eval()

for inputs, labels in val_loader:   # each iteration = 1 file dataset tensor
    inputs = inputs.to(device)
    labels = labels.to(device)
    
    with torch.no_grad():
        outputs = model(inputs)
        probs = torch.softmax(outputs, dim=1)
        confs, preds = torch.max(probs, dim=1)

        all_true.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())
        all_confidences.extend(confs.cpu().numpy())

# Compute Accuracy
all_true = np.array(all_true)
all_preds = np.array(all_preds)
accuracy = np.mean(all_true == all_preds)
print(f"Accuracy on Seen Flights: {accuracy:.2%}")

# update gridlines
plt.rcParams.update({
    "grid.alpha": 0})

# Plot Confusion Matrix
fig, ax = plt.subplots(figsize=(8, 6))
cm = confusion_matrix(all_true, all_preds, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=true_classes)
disp.plot(cmap="Oranges", values_format=".2f",ax=ax,colorbar=True)
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.title(f"Normalized Confusion Matrix for Seen Flights\nAccuracy: {accuracy:.2%}")
plt.show()

n_classes = len(true_classes)
conf_matrix = np.zeros((n_classes, n_classes))

for t, p, c in zip(all_true, all_preds, all_confidences):
    conf_matrix[t, p] += c

counts = np.bincount(all_true, minlength=n_classes)
conf_matrix = conf_matrix / counts[:, None]

fig, ax = plt.subplots(figsize=(8, 6))

im = ax.imshow(conf_matrix, cmap="Oranges")

# Add colorbar
cbar = fig.colorbar(im, ax=ax)

# Axis labels
ax.set_xticks(range(n_classes))
ax.set_yticks(range(n_classes))
ax.set_xticklabels(true_classes)
ax.set_yticklabels(true_classes)
ax.set_xlabel("Predicted Class")
ax.set_ylabel("True Class")
ax.set_title("Average Confidence per True–Predicted Class")

# ---- Add numeric annotations ----        
cmap = plt.get_cmap("Oranges")
threshold = conf_matrix.max() / 2

for i in range(n_classes):
    for j in range(n_classes):
        value = conf_matrix[i, j]

        if value > threshold:
            text_color = "white"
        else:
            text_color = cmap(1.0)  # darker orange tone

        ax.text(
            j, i,
            f"{value:.2f}",
            ha="center",
            va="center",
            color=text_color,
            fontweight= "regular"
        )

plt.show()
# Out:
# Accuracy on Seen Flights: 89.54%

# %% [markdown]
# ### Calculate Confusion Matrix / Confidence Interval for Unseen Flights

# %%
from curses import window

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

true_classes = encoder.classes_

correct_guesses = 0
total_guesses = 0
correctness = 0

all_true = []
all_preds = []
all_probs = []
all_loss = []
all_confidences = []

model.load_state_dict(torch.load(model_save_path))
model.to(device)
model.eval()

for input, label in test_loader:   # each iteration = 1 file dataset tensor
    input = input.to(device)
    # label = label.to(device)
    
    with torch.no_grad():
        outputs = model(input)
        # loss = criterion(outputs, label)
        probs = torch.softmax(outputs, dim=1)
        confs, preds = torch.max(probs, dim=1)

        all_true.extend(label.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())
        # all_loss.append(loss.item())
        all_confidences.extend(confs.cpu().numpy())

# %% [markdown]
# ### Plot Correctness over time for Test Flights

# %%
# housekeeping for plots
pred_window = 20
acc_window = 100
smoothed_probs = []
all_probs = np.array(all_probs)
all_true = np.array(all_true)
all_preds = np.array(all_preds)

# calculate smoothed guesses over time
for i in range(len(all_probs)):
    start = max(0, i - pred_window//2)
    end = min(len(all_probs), i + pred_window//2 + 1)
    avg_prob = np.mean(all_probs[start:end], axis=0)
    smoothed_probs.append(avg_prob)

smoothed_probs = np.array(smoothed_probs)
smoothed_preds = np.argmax(smoothed_probs, axis=1)

# calc accuracy
acc = np.mean(np.array(all_true[100:]) == np.array(all_preds[100:]))

# calculate rolling accuracy
correct = (all_true == all_preds).astype(float)
rolling_acc = np.convolve(correct, np.ones(acc_window) / acc_window, mode='valid')

# plot model guesses over time for each test flight but just plot dotts, not connecting them with lines
plt.figure(figsize=(14,5))
plt.step(range(len(all_true)), all_true, where='post', label="True")
plt.scatter(range(len(all_preds)), all_preds, s=4, color="orange", label="Predicted", zorder=3)
plt.yticks(np.arange(len(true_classes)), true_classes)
plt.xlabel("Sequence")
plt.ylabel("State")
plt.title("Predicted vs True State Over Time")
plt.legend()
plt.tight_layout()
plt.show()

# plot smoothed guesses
plt.figure(figsize=(14,5))
plt.step(range(len(all_true)), all_true, where='post', label="True")
plt.scatter(range(len(smoothed_preds)), smoothed_preds, s=4, color="orange", label="Smoothed Predicted", zorder=3)
plt.yticks(np.arange(len(true_classes)), true_classes)
plt.title(f"Averaged Predictions vs True State (prediction every {sequence_length/400*pred_window} s)")
plt.legend()
plt.tight_layout()
plt.show()

# plot rolling accuracy over time
plt.figure(figsize=(14,5))
plt.plot(rolling_acc)
plt.ylim(0,1)
plt.xlabel("Timestep")
plt.ylabel("Rolling Accuracy")
plt.title(f"Rolling Accuracy (window={acc_window})\nAvg Accuracy: {acc:.3f}")
plt.tight_layout()
plt.show()

# plt confidence over time
plt.figure(figsize=(14,5))
plt.plot(all_confidences)
plt.title("Prediction Confidence Over Time (L)")
plt.ylabel("Max Softmax Probability")
plt.xlabel("Sequence")
plt.ylim(0,1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plot Correctness / Confidence CM for Unseen Flights

# %%
# Compute sequential correctness
correct = np.array(all_preds) == np.array(all_true)

# update gridlines
plt.rcParams.update({
    "grid.alpha": 0})

# Compute Avg Accuracy
all_true = np.array(all_true)
all_preds = np.array(all_preds)
accuracy = np.mean(all_true == all_preds)
print(f"Accuracy on Unseen Flights: {accuracy:.2%}")

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(all_true, all_preds, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=true_classes)
disp.plot(cmap='Oranges', values_format=".2f")
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.title(f"Normalized Confusion Matrix for Unseen Flights\nAccuracy: {accuracy:.2%}")
plt.show()

# Calculate Confidence
conf_matrix = np.zeros((n_classes, n_classes))
for t, p, c in zip(all_true, all_preds, all_confidences):
    conf_matrix[t, p] += c

# Plot confidence matrix
counts = np.bincount(all_true, minlength=n_classes)
conf_matrix = conf_matrix / counts[:, None]
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(conf_matrix, cmap="Oranges")
cbar = fig.colorbar(im, ax=ax)
ax.set_xticks(range(n_classes))
ax.set_yticks(range(n_classes))
ax.set_xticklabels(true_classes)
ax.set_yticklabels(true_classes)
ax.set_xlabel("Predicted Class")
ax.set_ylabel("True Class")
ax.set_title("Average Confidence per True–Predicted Class")

# Add numbers to boxes    
cmap = plt.get_cmap("Oranges")
threshold = conf_matrix.max() / 2

# Set color of numbers in boxes
for i in range(n_classes):
    for j in range(n_classes):
        value = conf_matrix[i, j]

        if value > threshold:
            text_color = "white"
        else:
            text_color = cmap(1.0)

        ax.text(
            j, i,
            f"{value:.2f}",
            ha="center",
            va="center",
            color=text_color,
            fontweight= "regular"
        )
        
plt.show()
# Out:
# Accuracy on Unseen Flights: 81.92%
