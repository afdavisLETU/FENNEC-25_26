# %% [markdown]
# ## Wills Kookogey PyTorch Learning Enviromnment

# %% [markdown]
# ### Setup and Hyperparameters

# %% [markdown]
# Vars of interest
#
# {
#
#     "IMU_0":["GyrX", "GyrY", "GyrZ", "AccX", "AccY", "AccZ"],
#     "ATT":["DesRoll", "Roll", "DesPitch", "Pitch", "DesYaw", "Yaw"],
#     "RCIN":["C6", "C7"]
# }
#
# RCIN to determine when leak started for labeling, NOT used as model input

# %%
import fennec_ml as fn
import FID_utils as FID
import os
from pathlib import Path
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms  as transforms
import matplotlib.pyplot as plt
# %matplotlib inline

# hyper parameters
train_split = 0.8
input_size = 12
hidden_size = 64
num_classes = 4
num_epochs = 100
batch_size = 64
test_batch_size = 1
learning_rate = 0.001
weight_decay = 1e-3
dropout = 0.3
patience = 7  # number of epochs to wait for improvement before early stopping

sequence_length = 80
num_layers = 2

model_name = "fid_model_4_2.pth"
test_flights = ["194B_LR", "175B_LR", "191B_R", "195B_R", "173B_L", "188B_L", "189B_NONE", "178B_NONE"]

# %% [markdown]
# ### Folder Config

# %%
# folder config
main_dir = os.getcwd()
data_dir = os.path.join(main_dir, "DATA")
os.makedirs(data_dir, exist_ok=True)
excel_dir = os.path.join(data_dir, "RAW_DATA/FID3")
os.makedirs(excel_dir, exist_ok=True)
csv_dir = os.path.join(data_dir, "PROCESSED_DATA/FID4_2")
test_csv_dir = os.path.join(csv_dir, "test_flights")
os.makedirs(csv_dir, exist_ok=True)
os.makedirs(test_csv_dir, exist_ok=True)

json_path = os.path.join(main_dir, "vars_of_interest.json")

# Create models directory 
model_path = Path("models")
model_path.mkdir(parents=True, exist_ok=True)

# Create model save path
model_save_path = model_path / model_name

# convert excel data to csv
print("Using folder_cleaner() to convert from raw excel files to .csv's only including vars of interest.\nfolder_cleaner() output:")
fn.folder_cleaner(excel_dir, csv_dir, test_flight_names=test_flights, skip=True, overwrite=False, downsample=False)

# convert csv to numpy arrays
train_val_data = fn.csv_to_numpy(csv_dir, start_index=0)
test_data = fn.csv_to_numpy(test_csv_dir, start_index=0)

# standardize data
train_val_data, test_data = fn.scale(train_val_data, test_data, scaler="standard")

# get FID labels and leakstarts
train_val_labels, train_val_leakstarts = FID.get_FID_labels(csv_dir)
test_labels, test_leakstarts = FID.get_FID_labels(test_csv_dir)

print(f"Test labels: {test_labels}")
print(f"Test leakstarts: {test_leakstarts}")

print(f"train_val_labels ({len(train_val_labels)}): {train_val_labels}")
print(f"train_val_leakstarts ({len(train_val_leakstarts)}): {train_val_leakstarts}")
assert len(train_val_labels) == len(train_val_leakstarts), "MISMATCH!"
assert len(test_labels) == len(test_leakstarts), "MISMATCH!"

# nudge leakstarts back by 2 seconds to account for leak start (800 timesteps at 400hz)
train_val_leakstarts = [leakstart + 800 for leakstart in train_val_leakstarts]
test_leakstarts = [leakstart + 800 for leakstart in test_leakstarts]

# verify flights found
num_train_val_flights = len(train_val_labels)
print(f"Found {num_train_val_flights} flights for training and validation")

num_test_flights = len(test_labels)
print(f"Found {num_test_flights} flights for testing")

# segment and label data
dataset_dict = FID.segment_label_split_FID(train_val_data, test_data, train_val_labels, test_labels, train_val_leakstarts, test_leakstarts, sequence_length, train_split,shuffle=True)
# Out:
# Using folder_cleaner() to convert from raw excel files to .csv's only including vars of interest.
# folder_cleaner() output:
# 179B_LR.xlsx skipped due to existing duplicate.
# 182B_NONE.xlsx skipped due to existing duplicate.
# Warning: No saved leak start for skipped file 182B_NONE
# 205B_NONE.xlsx skipped due to existing duplicate.
# Warning: No saved leak start for skipped file 205B_NONE
# 193B_NONE.xlsx skipped due to existing duplicate.
# Warning: No saved leak start for skipped file 193B_NONE
# 187B_R.xlsx skipped due to existing duplicate.
# 169B_L.xlsx skipped due to existing duplicate.
# 172B_R.xlsx skipped due to existing duplicate.
# Sheet RCIN, upsampled by 40.0
# 178B_NONE.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_2/test_flights as 178B_NONE.csv
# Warning: No saved leak start for skipped file 178B_NONE
# 211B_NONE.xlsx skipped due to existing duplicate.
# Warning: No saved leak start for skipped file 211B_NONE
# 204B_L.xlsx skipped due to existing duplicate.
# 186B_LR.xlsx skipped due to existing duplicate.
# 214B_L.xlsx skipped due to existing duplicate.
# 196B_L.xlsx skipped due to existing duplicate.
# 168B_R.xlsx skipped due to existing duplicate.
# Sheet RCIN, upsampled by 40.0
# 173B_L.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_2/test_flights as 173B_L.csv
# 190B_LR.xlsx skipped due to existing duplicate.
# Sheet RCIN, upsampled by 40.0
# 175B_LR.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_2/test_flights as 175B_LR.csv
# 195B_R.xlsx skipped due to existing duplicate.
# 201B_NONE.xlsx skipped due to existing duplicate.
# Warning: No saved leak start for skipped file 201B_NONE
# 197B_NONE.xlsx skipped due to existing duplicate.
# Warning: No saved leak start for skipped file 197B_NONE
# 180B_R.xlsx skipped due to existing duplicate.
# 167B_LR.xlsx skipped due to existing duplicate.
# 174B_NONE.xlsx skipped due to existing duplicate.
# Warning: No saved leak start for skipped file 174B_NONE
# 208B_LR.xlsx skipped due to existing duplicate.
# 192B_L.xlsx skipped due to existing duplicate.
# 199B_R.xlsx skipped due to existing duplicate.
# 202B_LR.xlsx skipped due to existing duplicate.
# 200B_L.xlsx skipped due to existing duplicate.
# 210B_L.xlsx skipped due to existing duplicate.
# 194B_LR.xlsx skipped due to existing duplicate.
# 215B_NONE.xlsx skipped due to existing duplicate.
# Warning: No saved leak start for skipped file 215B_NONE
# 177B_L.xlsx skipped due to existing duplicate.
# 183B_NONE.xlsx skipped due to existing duplicate.
# Warning: No saved leak start for skipped file 183B_NONE
# 171B_LR.xlsx skipped due to existing duplicate.
# Sheet RCIN, upsampled by 40.0
# 191B_R.xlsx processed and saved to /Users/willsstoddard/Documents/Development/Python/FENNEC/FENNEC-25_26/DATA/PROCESSED_DATA/FID4_2/test_flights as 191B_R.csv
# 203B_R.xlsx skipped due to existing duplicate.
# 213B_R.xlsx skipped due to existing duplicate.
# 189B_NONE.xlsx skipped due to existing duplicate.
# Warning: No saved leak start for skipped file 189B_NONE
# 181B_L.xlsx skipped due to existing duplicate.
# 188B_L.xlsx skipped due to existing duplicate.
# 198B_LR.xlsx skipped due to existing duplicate.
# 212B_LR.xlsx skipped due to existing duplicate.
# 176B_R.xlsx skipped due to existing duplicate.
# 209B_R.xlsx skipped due to existing duplicate.
# Importing 167B_LR.csv with shape (70840, 12)...
# Importing 168B_R.csv with shape (55420, 12)...
# Importing 169B_L.csv with shape (62434, 12)...
# Importing 171B_LR.csv with shape (35840, 12)...
# Importing 172B_R.csv with shape (26240, 12)...
# Importing 174B_NONE.csv with shape (42483, 12)...
# Importing 176B_R.csv with shape (46600, 12)...
# Importing 177B_L.csv with shape (47720, 12)...
# Importing 179B_LR.csv with shape (49920, 12)...
# Importing 180B_R.csv with shape (52360, 12)...
# Importing 181B_L.csv with shape (47400, 12)...
# Importing 182B_NONE.csv with shape (44750, 12)...
# Importing 183B_NONE.csv with shape (49200, 12)...
# Importing 186B_LR.csv with shape (55320, 12)...
# Importing 187B_R.csv with shape (51471, 12)...
# Importing 190B_LR.csv with shape (54040, 12)...
# Importing 192B_L.csv with shape (56680, 12)...
# Importing 193B_NONE.csv with shape (51840, 12)...
# Importing 196B_L.csv with shape (62760, 12)...
# Importing 197B_NONE.csv with shape (71240, 12)...
# Importing 198B_LR.csv with shape (66720, 12)...
# Importing 199B_R.csv with shape (53240, 12)...
# Importing 200B_L.csv with shape (51037, 12)...
# Importing 201B_NONE.csv with shape (76440, 12)...
# Importing 202B_LR.csv with shape (81280, 12)...
# Importing 203B_R.csv with shape (78753, 12)...
# Importing 204B_L.csv with shape (74032, 12)...
# Importing 205B_NONE.csv with shape (103160, 12)...
# Importing 208B_LR.csv with shape (42360, 12)...
# Importing 209B_R.csv with shape (49760, 12)...
# Importing 210B_L.csv with shape (63830, 12)...
# Importing 211B_NONE.csv with shape (53245, 12)...
# Importing 212B_LR.csv with shape (53760, 12)...
# Importing 213B_R.csv with shape (53640, 12)...
# Importing 214B_L.csv with shape (51600, 12)...
# Importing 215B_NONE.csv with shape (57880, 12)...
# Importing 173B_L.csv with shape (44920, 12)...
# Importing 175B_LR.csv with shape (51223, 12)...
# Importing 178B_NONE.csv with shape (42920, 12)...
# Importing 188B_L.csv with shape (52176, 12)...
# Importing 189B_NONE.csv with shape (50960, 12)...
# Importing 191B_R.csv with shape (60800, 12)...
# Importing 194B_LR.csv with shape (68195, 12)...
# Importing 195B_R.csv with shape (55080, 12)...
# Test labels: ['L', 'LR', 'NONE', 'L', 'NONE', 'R', 'LR', 'R']
# Test leakstarts: [6880, 11800, 0, 8160, 0, 7000, 7120, 7560]
# train_val_labels (36): ['LR', 'R', 'L', 'LR', 'R', 'NONE', 'R', 'L', 'LR', 'R', 'L', 'NONE', 'NONE', 'LR', 'R', 'LR', 'L', 'NONE', 'L', 'NONE', 'LR', 'R', 'L', 'NONE', 'LR', 'R', 'L', 'NONE', 'LR', 'R', 'L', 'NONE', 'LR', 'R', 'L', 'NONE']
# train_val_leakstarts (36): [12680, 4320, 13600, 7920, 6200, 0, 7400, 6160, 9960, 8000, 9280, 0, 0, 6040, 6000, 11480, 8760, 0, 6840, 0, 6880, 7760, 7680, 0, 23400, 23280, 23640, 0, 6280, 7080, 6720, 0, 7640, 7160, 7440, 0]
# Found 36 flights for training and validation
# Found 8 flights for testing
# Segments shuffled
# Segments not shuffled
# All data segmented and labeled!
# Training_Sets: 20442
# Validation_Sets: 5111
# Testing_Sets: 5326

# %% [markdown]
# ### Check Data Shape

# %%
print(dataset_dict["Training_Set"]["sets"].shape)
print(dataset_dict["Training_Set"]["labels"].shape)
print(dataset_dict["Validation_Set"]["sets"].shape)
print(dataset_dict["Validation_Set"]["labels"].shape)
print(dataset_dict["Testing_Set"]["sets"].shape)
print(dataset_dict["Testing_Set"]["labels"].shape)
# Out:
# (20442, 80, 12)
# (20442,)
# (5111, 80, 12)
# (5111,)
# (5326, 80, 12)
# (5326,)

# %% [markdown]
# ### Convert data to tensors

# %%
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler, TensorDataset
import numpy as np

encoder = LabelEncoder()

encoded_labels_train = encoder.fit_transform(dataset_dict["Training_Set"]["labels"])
print(encoder.classes_)
encoded_labels_val   = encoder.transform(dataset_dict["Validation_Set"]["labels"])
encoded_labels_test  = encoder.transform(dataset_dict["Testing_Set"]["labels"])

print(f"Test labels raw: {test_labels}")
print(f"Test leakstarts: {test_leakstarts}")

# After encoding
print("Test label distribution:")
for i, cls in enumerate(encoder.classes_):
    count = np.sum(encoded_labels_test == i)
    print(f"  {cls} ({i}): {count} segments")

input_train = torch.from_numpy(dataset_dict["Training_Set"]["sets"]).type(torch.float)
output_train = torch.from_numpy(encoded_labels_train).long()

input_val = torch.from_numpy(dataset_dict["Validation_Set"]["sets"]).type(torch.float)
output_val = torch.from_numpy(encoded_labels_val).long()

input_test = torch.from_numpy(dataset_dict["Testing_Set"]["sets"]).type(torch.float)
output_test = torch.from_numpy(encoded_labels_test).long()

# stack inputs and outputs
train_data = TensorDataset(input_train, output_train)
val_data = TensorDataset(input_val, output_val)
test_data = TensorDataset(input_test, output_test)

# data loader
class_counts = np.bincount(output_train.numpy())
print(f'Num data segments per class: {class_counts}')
weights = 1. / class_counts
print(f'Weights per class: {weights}')
sample_weights = [weights[label] for label in output_train]
sampler = WeightedRandomSampler(sample_weights, num_samples=len(sample_weights), replacement=True)

# try shuffle = false
train_loader = DataLoader(train_data, batch_size=batch_size, sampler=sampler)
val_loader   = DataLoader(val_data, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(test_data, batch_size=test_batch_size, shuffle=False)
# Out:
# ['L' 'LR' 'NONE' 'R']
# Test labels raw: ['L', 'LR', 'NONE', 'L', 'NONE', 'R', 'LR', 'R']
# Test leakstarts: [7680, 12600, 800, 8960, 800, 7800, 7920, 8360]
# Test label distribution:
#   L (0): 1005 segments
#   LR (1): 1236 segments
#   NONE (2): 1838 segments
#   R (3): 1247 segments
# Num data segments per class: [4213 4123 8344 3762]
# Weights per class: [0.00023736 0.00024254 0.00011985 0.00026582]

# %% [markdown]
# ### Build Model

# %%
from pathlib import Path
import torch
import torch.nn as nn
from torch.optim import Adam
import torchvision.transforms  as transforms
import matplotlib.pyplot as plt
# %matplotlib inline

# Device config
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("MPS device found.")
else:
    print("MPS device not found. Using CPU.")
    device = torch.device("cpu") # Fallback to CPU if MPS is not available

# LSTM Model
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout=dropout):
        super(LSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout if num_layers > 1 else 0)
        self.fc1 = nn.Linear(hidden_size, hidden_size // 2)
        self.dropout = nn.Dropout(dropout)
        self.fc2 = nn.Linear(hidden_size // 2, num_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        out, _ = self.lstm(x)   # LSTM returns (output, (h_n, c_n)) — the _ unpacks both
        out = out[:, -1, :]
        out = self.fc1(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.fc2(out)
        return out

model = LSTM(input_size=input_size, hidden_size=hidden_size, num_classes=num_classes, num_layers=num_layers).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
best_val_loss = float('inf')
# Out:
# MPS device found.

# %% [markdown]
# ### Train Model

# %%
# Train Loop

# arrays to store training curve data
train_losses = []
val_losses = []
val_accuracies = []

no_improvement_epochs = 0

model.train()

for epoch in range(num_epochs):
    # Training
    model.train()
    running_loss = 0
    for input, output in train_loader:
        # print(f"Input shape: {input.shape}, Output shape: {output.shape}")
        input, output = input.to(device), output.to(device)
        optimizer.zero_grad()
        model_outputs = model(input)
        loss = criterion(model_outputs,output)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * input.size(0)
    epoch_loss = running_loss / len(train_data)

    # Validation
    model.eval()
    val_loss = 0
    correct = 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            loss = criterion(outputs,y_batch)
            val_loss += loss.item() * X_batch.size(0)
            preds = torch.argmax(outputs, dim=1)
            correct += (preds == y_batch).sum().item()
    val_loss /= len(val_data)
    val_acc = correct / len(val_data)

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
    
    # save each epoch's perormance
    train_losses.append(epoch_loss)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), model_save_path)
        print(f"✅ Saved best model at epoch {epoch+1}")
        no_improvement_epochs = 0 # reset counter if model improves
    
    else:
        no_improvement_epochs += 1
        if no_improvement_epochs >= patience:
            print("⏰ Early stopping")
            break

print("Training complete!")

epochs = range(1, len(train_losses) + 1)
# Out:
# Epoch 1/100, Train Loss: 1.3701, Val Loss: 1.3599, Val Acc: 0.3537
# ✅ Saved best model at epoch 1
# Epoch 2/100, Train Loss: 1.3601, Val Loss: 1.3429, Val Acc: 0.3496
# ✅ Saved best model at epoch 2
# Epoch 3/100, Train Loss: 1.3577, Val Loss: 1.3285, Val Acc: 0.3629
# ✅ Saved best model at epoch 3
# Epoch 4/100, Train Loss: 1.3516, Val Loss: 1.3195, Val Acc: 0.3649
# ✅ Saved best model at epoch 4
# Epoch 5/100, Train Loss: 1.3376, Val Loss: 1.2852, Val Acc: 0.4089
# ✅ Saved best model at epoch 5
# Epoch 6/100, Train Loss: 1.3142, Val Loss: 1.2835, Val Acc: 0.4101
# ✅ Saved best model at epoch 6
# Epoch 7/100, Train Loss: 1.2739, Val Loss: 1.2858, Val Acc: 0.3976
# Epoch 8/100, Train Loss: 1.2627, Val Loss: 1.2349, Val Acc: 0.4240
# ✅ Saved best model at epoch 8
# Epoch 9/100, Train Loss: 1.2415, Val Loss: 1.2410, Val Acc: 0.4209
# Epoch 10/100, Train Loss: 1.2276, Val Loss: 1.2623, Val Acc: 0.4034
# Epoch 11/100, Train Loss: 1.2139, Val Loss: 1.1890, Val Acc: 0.4529
# ✅ Saved best model at epoch 11
# Epoch 12/100, Train Loss: 1.1960, Val Loss: 1.1831, Val Acc: 0.4555
# ✅ Saved best model at epoch 12
# Epoch 13/100, Train Loss: 1.1857, Val Loss: 1.1859, Val Acc: 0.4623
# Epoch 14/100, Train Loss: 1.1595, Val Loss: 1.1897, Val Acc: 0.4850
# Epoch 15/100, Train Loss: 1.1462, Val Loss: 1.1606, Val Acc: 0.4991
# ✅ Saved best model at epoch 15
# Epoch 16/100, Train Loss: 1.0936, Val Loss: 1.0476, Val Acc: 0.5523
# ✅ Saved best model at epoch 16
# Epoch 17/100, Train Loss: 1.0096, Val Loss: 0.9802, Val Acc: 0.5752
# ✅ Saved best model at epoch 17
# Epoch 18/100, Train Loss: 0.9344, Val Loss: 0.9483, Val Acc: 0.5879
# ✅ Saved best model at epoch 18
# Epoch 19/100, Train Loss: 0.8741, Val Loss: 0.8601, Val Acc: 0.6326
# ✅ Saved best model at epoch 19
# Epoch 20/100, Train Loss: 0.7717, Val Loss: 0.8414, Val Acc: 0.6478
# ✅ Saved best model at epoch 20
# Epoch 21/100, Train Loss: 0.7035, Val Loss: 0.6961, Val Acc: 0.6969
# ✅ Saved best model at epoch 21
# Epoch 22/100, Train Loss: 0.6653, Val Loss: 0.6640, Val Acc: 0.6954
# ✅ Saved best model at epoch 22
# Epoch 23/100, Train Loss: 0.6419, Val Loss: 0.6522, Val Acc: 0.7132
# ✅ Saved best model at epoch 23
# Epoch 24/100, Train Loss: 0.6183, Val Loss: 0.6409, Val Acc: 0.7253
# ✅ Saved best model at epoch 24
# Epoch 25/100, Train Loss: 0.5909, Val Loss: 0.6192, Val Acc: 0.7247
# ✅ Saved best model at epoch 25
# Epoch 26/100, Train Loss: 0.5751, Val Loss: 0.5915, Val Acc: 0.7496
# ✅ Saved best model at epoch 26
# Epoch 27/100, Train Loss: 0.5658, Val Loss: 0.5571, Val Acc: 0.7603
# ✅ Saved best model at epoch 27
# Epoch 28/100, Train Loss: 0.5483, Val Loss: 0.5602, Val Acc: 0.7572
# Epoch 29/100, Train Loss: 0.5245, Val Loss: 0.5499, Val Acc: 0.7691
# ✅ Saved best model at epoch 29
# Epoch 30/100, Train Loss: 0.5339, Val Loss: 0.5288, Val Acc: 0.7807
# ✅ Saved best model at epoch 30
# Epoch 31/100, Train Loss: 0.5183, Val Loss: 0.6124, Val Acc: 0.7433
# Epoch 32/100, Train Loss: 0.5001, Val Loss: 0.5121, Val Acc: 0.7887
# ✅ Saved best model at epoch 32
# Epoch 33/100, Train Loss: 0.4845, Val Loss: 0.5195, Val Acc: 0.7860
# Epoch 34/100, Train Loss: 0.4849, Val Loss: 0.4996, Val Acc: 0.7996
# ✅ Saved best model at epoch 34
# Epoch 35/100, Train Loss: 0.4715, Val Loss: 0.4852, Val Acc: 0.8040
# ✅ Saved best model at epoch 35
# Epoch 36/100, Train Loss: 0.4643, Val Loss: 0.5445, Val Acc: 0.7760
# Epoch 37/100, Train Loss: 0.4499, Val Loss: 0.5064, Val Acc: 0.7948
# Epoch 38/100, Train Loss: 0.4545, Val Loss: 0.4980, Val Acc: 0.7906
# Epoch 39/100, Train Loss: 0.4343, Val Loss: 0.5685, Val Acc: 0.7644
# Epoch 40/100, Train Loss: 0.4317, Val Loss: 0.4571, Val Acc: 0.8124
# ✅ Saved best model at epoch 40
# Epoch 41/100, Train Loss: 0.4229, Val Loss: 0.4992, Val Acc: 0.7889
# Epoch 42/100, Train Loss: 0.4125, Val Loss: 0.4836, Val Acc: 0.8000
# Epoch 43/100, Train Loss: 0.4188, Val Loss: 0.4402, Val Acc: 0.8292
# ✅ Saved best model at epoch 43
# Epoch 44/100, Train Loss: 0.4001, Val Loss: 0.4392, Val Acc: 0.8255
# ✅ Saved best model at epoch 44
# Epoch 45/100, Train Loss: 0.3906, Val Loss: 0.4606, Val Acc: 0.8157
# Epoch 46/100, Train Loss: 0.3961, Val Loss: 0.4755, Val Acc: 0.8034
# Epoch 47/100, Train Loss: 0.3864, Val Loss: 0.4451, Val Acc: 0.8284
# Epoch 48/100, Train Loss: 0.3769, Val Loss: 0.4810, Val Acc: 0.8090
# Epoch 49/100, Train Loss: 0.3674, Val Loss: 0.4064, Val Acc: 0.8431
# ✅ Saved best model at epoch 49
# Epoch 50/100, Train Loss: 0.3507, Val Loss: 0.4634, Val Acc: 0.8212
# Epoch 51/100, Train Loss: 0.3537, Val Loss: 0.4287, Val Acc: 0.8321
# Epoch 52/100, Train Loss: 0.3604, Val Loss: 0.4584, Val Acc: 0.8176
# Epoch 53/100, Train Loss: 0.3414, Val Loss: 0.4435, Val Acc: 0.8298
# Epoch 54/100, Train Loss: 0.3419, Val Loss: 0.4686, Val Acc: 0.8126
# Epoch 55/100, Train Loss: 0.3342, Val Loss: 0.4382, Val Acc: 0.8272
# Epoch 56/100, Train Loss: 0.3392, Val Loss: 0.4272, Val Acc: 0.8400
# ⏰ Early stopping
# Training complete!

# %% [markdown]
# ### Plot Train/Val and Acc Curves

# %%
# Set Plot Styles
import matplotlib.pyplot as plt

plt.rcParams.update({
    "figure.figsize": (8, 6),
    "axes.edgecolor": "black",
    "axes.linewidth": .9,
    "axes.labelsize": 12,
    "axes.titlesize": 13,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "lines.linewidth": 1.8,
    "grid.linestyle": "--",
    "grid.alpha": 0.4,
})

# plot training and validation loss curves

plt.figure()
plt.plot(epochs, train_losses, label="Train Loss")
plt.plot(epochs, val_losses, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training & Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

plt.figure()
plt.plot(epochs, val_accuracies, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Plot Confusion Matrix / Confidence Interval for Seen Flights

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

true_classes = encoder.classes_

correct_guesses = 0
total_guesses = 0
correctness = 0

all_true = []
all_preds = []
all_probs = []
all_confidences = []

model.load_state_dict(torch.load(model_save_path))
model.to(device)
model.eval()

for inputs, labels in val_loader:   # each iteration = 1 file dataset tensor
    inputs = inputs.to(device)
    labels = labels.to(device)
    
    with torch.no_grad():
        outputs = model(inputs)
        probs = torch.softmax(outputs, dim=1)
        confs, preds = torch.max(probs, dim=1)

        all_true.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())
        all_confidences.extend(confs.cpu().numpy())

# Compute Accuracy
all_true = np.array(all_true)
all_preds = np.array(all_preds)
accuracy = np.mean(all_true == all_preds)
print(f"Accuracy on Seen Flights: {accuracy:.2%}")

# update gridlines
plt.rcParams.update({
    "grid.alpha": 0})

# Plot Confusion Matrix
fig, ax = plt.subplots(figsize=(8, 6))
cm = confusion_matrix(all_true, all_preds, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=true_classes)
disp.plot(cmap="Oranges", values_format=".2f",ax=ax,colorbar=True)
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.title(f"Normalized Confusion Matrix for Seen Flights\nAccuracy: {accuracy:.2%}")
plt.show()

n_classes = len(true_classes)
conf_matrix = np.zeros((n_classes, n_classes))

for t, p, c in zip(all_true, all_preds, all_confidences):
    conf_matrix[t, p] += c

counts = np.bincount(all_true, minlength=n_classes)
conf_matrix = conf_matrix / counts[:, None]

fig, ax = plt.subplots(figsize=(8, 6))

im = ax.imshow(conf_matrix, cmap="Oranges")

# Add colorbar
cbar = fig.colorbar(im, ax=ax)

# Axis labels
ax.set_xticks(range(n_classes))
ax.set_yticks(range(n_classes))
ax.set_xticklabels(true_classes)
ax.set_yticklabels(true_classes)
ax.set_xlabel("Predicted Class")
ax.set_ylabel("True Class")
ax.set_title("Average Confidence per True–Predicted Class")

# ---- Add numeric annotations ----        
cmap = plt.get_cmap("Oranges")
threshold = conf_matrix.max() / 2

for i in range(n_classes):
    for j in range(n_classes):
        value = conf_matrix[i, j]

        if value > threshold:
            text_color = "white"
        else:
            text_color = cmap(1.0)  # darker orange tone

        ax.text(
            j, i,
            f"{value:.2f}",
            ha="center",
            va="center",
            color=text_color,
            fontweight= "regular"
        )

plt.show()
# Out:
# Accuracy on Seen Flights: 83.76%

# %% [markdown]
# ### Calculate Confusion Matrix / Confidence Interval for Unseen Flights

# %%
from curses import window

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

true_classes = encoder.classes_

correct_guesses = 0
total_guesses = 0
correctness = 0

all_true = []
all_preds = []
all_probs = []
all_loss = []
all_confidences = []

model.load_state_dict(torch.load(model_save_path))
model.to(device)
model.eval()

for input, label in test_loader:   # each iteration = 1 file dataset tensor
    input = input.to(device)
    # label = label.to(device)
    
    with torch.no_grad():
        outputs = model(input)
        # loss = criterion(outputs, label)
        probs = torch.softmax(outputs, dim=1)
        confs, preds = torch.max(probs, dim=1)

        all_true.extend(label.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())
        # all_loss.append(loss.item())
        all_confidences.extend(confs.cpu().numpy())

# %% [markdown]
# ### Plot Correctness over time for Test Flights

# %%
# housekeeping for plots
pred_window = 10
acc_window = 100
smoothed_probs = []
all_probs = np.array(all_probs)
all_true = np.array(all_true)
all_preds = np.array(all_preds)

# calculate smoothed guesses over time
for i in range(len(all_probs)):
    start = max(0, i - pred_window//2)
    end = min(len(all_probs), i + pred_window//2 + 1)
    avg_prob = np.mean(all_probs[start:end], axis=0)
    smoothed_probs.append(avg_prob)

smoothed_probs = np.array(smoothed_probs)
smoothed_preds = np.argmax(smoothed_probs, axis=1)

# calc accuracy
acc = np.mean(np.array(all_true[100:]) == np.array(all_preds[100:]))

# calculate rolling accuracy
correct = (all_true == all_preds).astype(float)
rolling_acc = np.convolve(correct, np.ones(acc_window) / acc_window, mode='valid')

# plot model guesses over time for each test flight but just plot dotts, not connecting them with lines
plt.figure(figsize=(14,5))
plt.step(range(len(all_true)), all_true, where='post', label="True")
plt.scatter(range(len(all_preds)), all_preds, s=4, color="orange", label="Predicted", zorder=3)
plt.yticks(np.arange(len(true_classes)), true_classes)
plt.xlabel("Sequence")
plt.ylabel("State")
plt.title("Predicted vs True State Over Time")
plt.legend()
plt.tight_layout()
plt.show()

# plot smoothed guesses
plt.figure(figsize=(14,5))
plt.step(range(len(all_true)), all_true, where='post', label="True")
plt.scatter(range(len(smoothed_preds)), smoothed_preds, s=4, color="orange", label="Smoothed Predicted", zorder=3)
plt.yticks(np.arange(len(true_classes)), true_classes)
plt.title(f"Smoothed Predictions vs True State (prediction every {sequence_length/400*pred_window} s)")
plt.legend()
plt.tight_layout()
plt.show()

# plot rolling accuracy over time
plt.figure(figsize=(14,5))
plt.plot(rolling_acc)
plt.ylim(0,1)
plt.xlabel("Timestep")
plt.ylabel("Rolling Accuracy")
plt.title(f"Rolling Accuracy (window={acc_window})\nAvg Accuracy: {acc:.3f}")
plt.tight_layout()
plt.show()

# plt confidence over time
plt.figure(figsize=(14,5))
plt.plot(all_confidences)
plt.title("Prediction Confidence Over Time (L)")
plt.ylabel("Max Softmax Probability")
plt.xlabel("Sequence")
plt.ylim(0,1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plot Correctness / Confidence CM for Unseen Flights

# %%
# Compute sequential correctness
correct = np.array(all_preds) == np.array(all_true)

# update gridlines
plt.rcParams.update({
    "grid.alpha": 0})

# Compute Avg Accuracy
all_true = np.array(all_true)
all_preds = np.array(all_preds)
accuracy = np.mean(all_true == all_preds)
print(f"Accuracy on Unseen Flights: {accuracy:.2%}")

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(all_true, all_preds, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=true_classes)
disp.plot(cmap='Oranges', values_format=".2f")
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.title(f"Normalized Confusion Matrix for Unseen Flights\nAccuracy: {accuracy:.2%}")
plt.show()

# Calculate Confidence
conf_matrix = np.zeros((n_classes, n_classes))
for t, p, c in zip(all_true, all_preds, all_confidences):
    conf_matrix[t, p] += c

# Plot confidence matrix
counts = np.bincount(all_true, minlength=n_classes)
conf_matrix = conf_matrix / counts[:, None]
fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(conf_matrix, cmap="Oranges")
cbar = fig.colorbar(im, ax=ax)
ax.set_xticks(range(n_classes))
ax.set_yticks(range(n_classes))
ax.set_xticklabels(true_classes)
ax.set_yticklabels(true_classes)
ax.set_xlabel("Predicted Class")
ax.set_ylabel("True Class")
ax.set_title("Average Confidence per True–Predicted Class")

# Add numbers to boxes    
cmap = plt.get_cmap("Oranges")
threshold = conf_matrix.max() / 2

# Set color of numbers in boxes
for i in range(n_classes):
    for j in range(n_classes):
        value = conf_matrix[i, j]

        if value > threshold:
            text_color = "white"
        else:
            text_color = cmap(1.0)

        ax.text(
            j, i,
            f"{value:.2f}",
            ha="center",
            va="center",
            color=text_color,
            fontweight= "regular"
        )
        
plt.show()
# Out:
# Accuracy on Unseen Flights: 67.01%
